# %% [markdown]
# # Download images
# ---
# ### This script downloads images from https://battlecatsinfo.github.io saving to [cat](data/cat) an [background](data/background) respectively.

# %%
import os
import logging
import urllib
from urllib.error import HTTPError
from concurrent.futures import ThreadPoolExecutor
import requests
from furl import furl
from itertools import count

cats_path = 'data/cat'
bg_path = 'data/background'
base_url = furl('https://battlecatsinfo.github.io')

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ### Helper function

# %%
from itertools import takewhile


def find_max_index(url: str):
    def key(index: int):
        f = url.format(id=index)
        res = requests.head(f)
        logger.info(f'{f} returned {res.status_code}')
        return res.status_code == 200

    p = list(takewhile(key, (2 ** i for i in count())))
    lo = p[-1]
    hi = 2 * lo
    while lo < hi:
        mid = (lo + hi) // 2
        if key(mid):
            lo = mid + 1
        else:
            hi = mid
    return lo - 1

# %% [markdown]
# ### Download cat images

# %%
# Download cat images

_cats_url = f'{base_url.url}/img/u/{{id:03}}/{{fcs}}/uni{{id:03}}_{{fcs}}00.png'


def download_cats(start: int = 0, force_download=False):
    if not os.path.exists(cats_path):
        os.mkdir(cats_path)
    elif not force_download and any((file.endswith('.png') for file in os.listdir(cats_path))):
        return

    def download(cat_id: int):
        first = _cats_url.format(id=cat_id, fcs='f')
        if requests.head(first).status_code != 200:
            logging.warning(f'failed to download cat[{cat_id}]')
            return
        try:
            for fcs in ['f', 'c', 's']:
                src = _cats_url.format(id=cat_id, fcs=fcs)
                logging.debug(f'Downloading {src}')
                output_path = f'{cats_path}/{cat_id:003}_{fcs}.png'
                image = requests.get(src)
                with open(output_path, "wb") as f:
                    f.write(image.content)
        except HTTPError:
            pass
        logging.info(f'downloaded cat[{cat_id}]')

    if not os.path.exists(cats_path):
        os.mkdir(cats_path)
    elif not force_download and any((file.endswith('.png') for file in os.listdir(cats_path))):
        return

    f_url = f'{base_url.url}/img/u/{{id:03}}/f/uni{{id:03}}_f00.png'
    max_index = find_max_index(f_url)
    logging.info(f'maximum index is {max_index}')

    with ThreadPoolExecutor(max_workers=10) as executor:
        for i in range(start, max_index + 1):
            executor.submit(download, i)


download_cats()
# Out:
# INFO:root:maximum index is 761
# INFO:root:downloaded cat[2]
# INFO:root:downloaded cat[0]
# INFO:root:downloaded cat[8]
# INFO:root:downloaded cat[9]
# INFO:root:downloaded cat[4]
# INFO:root:downloaded cat[5]
# INFO:root:downloaded cat[1]
# INFO:root:downloaded cat[7]
# INFO:root:downloaded cat[3]
# INFO:root:downloaded cat[6]
# INFO:root:downloaded cat[10]
# INFO:root:downloaded cat[13]
# INFO:root:downloaded cat[14]
# INFO:root:downloaded cat[12]
# INFO:root:downloaded cat[16]
# INFO:root:downloaded cat[11]
# INFO:root:downloaded cat[15]
# INFO:root:downloaded cat[18]
# INFO:root:downloaded cat[19]
# INFO:root:downloaded cat[17]
# INFO:root:downloaded cat[20]
# INFO:root:downloaded cat[22]
# INFO:root:downloaded cat[24]
# INFO:root:downloaded cat[21]
# INFO:root:downloaded cat[25]
# INFO:root:downloaded cat[23]
# INFO:root:downloaded cat[26]
# INFO:root:downloaded cat[28]
# INFO:root:downloaded cat[27]
# INFO:root:downloaded cat[29]
# INFO:root:downloaded cat[30]
# INFO:root:downloaded cat[31]
# INFO:root:downloaded cat[32]
# INFO:root:downloaded cat[34]
# INFO:root:downloaded cat[35]
# INFO:root:downloaded cat[33]
# INFO:root:downloaded cat[36]
# INFO:root:downloaded cat[39]
# INFO:root:downloaded cat[40]
# INFO:root:downloaded cat[38]
# INFO:root:downloaded cat[37]
# INFO:root:downloaded cat[42]
# INFO:root:downloaded cat[41]
# INFO:root:downloaded cat[44]
# INFO:root:downloaded cat[43]
# INFO:root:downloaded cat[45]
# INFO:root:downloaded cat[46]
# INFO:root:downloaded cat[51]
# INFO:root:downloaded cat[47]
# INFO:root:downloaded cat[48]
# INFO:root:downloaded cat[49]
# INFO:root:downloaded cat[50]
# INFO:root:downloaded cat[53]
# INFO:root:downloaded cat[55]
# INFO:root:downloaded cat[52]
# INFO:root:downloaded cat[56]
# INFO:root:downloaded cat[54]
# INFO:root:downloaded cat[58]
# INFO:root:downloaded cat[57]
# INFO:root:downloaded cat[59]
# INFO:root:downloaded cat[60]
# INFO:root:downloaded cat[61]
# INFO:root:downloaded cat[64]
# INFO:root:downloaded cat[62]
# INFO:root:downloaded cat[63]
# INFO:root:downloaded cat[65]
# INFO:root:downloaded cat[66]
# INFO:root:downloaded cat[67]
# INFO:root:downloaded cat[71]
# INFO:root:downloaded cat[68]
# INFO:root:downloaded cat[72]
# INFO:root:downloaded cat[73]
# INFO:root:downloaded cat[70]
# INFO:root:downloaded cat[69]
# INFO:root:downloaded cat[74]
# INFO:root:downloaded cat[76]
# INFO:root:downloaded cat[75]
# INFO:root:downloaded cat[77]
# INFO:root:downloaded cat[78]
# INFO:root:downloaded cat[79]
# INFO:root:downloaded cat[80]
# INFO:root:downloaded cat[83]
# INFO:root:downloaded cat[84]
# INFO:root:downloaded cat[81]
# INFO:root:downloaded cat[82]
# INFO:root:downloaded cat[85]
# INFO:root:downloaded cat[86]
# INFO:root:downloaded cat[87]
# INFO:root:downloaded cat[88]
# INFO:root:downloaded cat[90]
# INFO:root:downloaded cat[89]
# INFO:root:downloaded cat[91]
# INFO:root:downloaded cat[92]
# INFO:root:downloaded cat[95]
# INFO:root:downloaded cat[93]
# INFO:root:downloaded cat[96]
# INFO:root:downloaded cat[94]
# INFO:root:downloaded cat[97]
# INFO:root:downloaded cat[100]
# INFO:root:downloaded cat[98]
# INFO:root:downloaded cat[99]
# INFO:root:downloaded cat[101]
# INFO:root:downloaded cat[105]
# INFO:root:downloaded cat[106]
# INFO:root:downloaded cat[102]
# INFO:root:downloaded cat[103]
# INFO:root:downloaded cat[104]
# INFO:root:downloaded cat[107]
# INFO:root:downloaded cat[109]
# INFO:root:downloaded cat[108]
# INFO:root:downloaded cat[110]
# INFO:root:downloaded cat[111]
# INFO:root:downloaded cat[114]
# INFO:root:downloaded cat[112]
# INFO:root:downloaded cat[113]
# INFO:root:downloaded cat[115]
# INFO:root:downloaded cat[116]
# INFO:root:downloaded cat[117]
# INFO:root:downloaded cat[118]
# INFO:root:downloaded cat[124]
# INFO:root:downloaded cat[119]
# INFO:root:downloaded cat[125]
# INFO:root:downloaded cat[120]
# INFO:root:downloaded cat[121]
# INFO:root:downloaded cat[123]
# INFO:root:downloaded cat[122]
# INFO:root:downloaded cat[126]
# INFO:root:downloaded cat[128]
# INFO:root:downloaded cat[127]
# INFO:root:downloaded cat[130]
# INFO:root:downloaded cat[131]
# INFO:root:downloaded cat[129]
# INFO:root:downloaded cat[132]
# INFO:root:downloaded cat[134]
# INFO:root:downloaded cat[135]
# INFO:root:downloaded cat[136]
# INFO:root:downloaded cat[133]
# INFO:root:downloaded cat[137]
# INFO:root:downloaded cat[141]
# INFO:root:downloaded cat[138]
# INFO:root:downloaded cat[140]
# INFO:root:downloaded cat[139]
# INFO:root:downloaded cat[142]
# INFO:root:downloaded cat[143]
# INFO:root:downloaded cat[144]
# INFO:root:downloaded cat[145]
# INFO:root:downloaded cat[146]
# INFO:root:downloaded cat[147]
# INFO:root:downloaded cat[148]
# INFO:root:downloaded cat[150]
# INFO:root:downloaded cat[149]
# INFO:root:downloaded cat[151]
# INFO:root:downloaded cat[152]
# INFO:root:downloaded cat[155]
# INFO:root:downloaded cat[153]
# INFO:root:downloaded cat[154]
# INFO:root:downloaded cat[156]
# INFO:root:downloaded cat[157]
# INFO:root:downloaded cat[158]
# INFO:root:downloaded cat[159]
# INFO:root:downloaded cat[161]
# INFO:root:downloaded cat[160]
# INFO:root:downloaded cat[162]
# INFO:root:downloaded cat[163]
# INFO:root:downloaded cat[164]
# INFO:root:downloaded cat[165]
# INFO:root:downloaded cat[166]
# INFO:root:downloaded cat[168]
# INFO:root:downloaded cat[167]
# INFO:root:downloaded cat[169]
# INFO:root:downloaded cat[170]
# INFO:root:downloaded cat[171]
# INFO:root:downloaded cat[172]
# INFO:root:downloaded cat[174]
# INFO:root:downloaded cat[173]
# INFO:root:downloaded cat[175]
# INFO:root:downloaded cat[176]
# INFO:root:downloaded cat[180]
# INFO:root:downloaded cat[177]
# INFO:root:downloaded cat[179]
# INFO:root:downloaded cat[178]
# INFO:root:downloaded cat[181]
# INFO:root:downloaded cat[182]
# INFO:root:downloaded cat[185]
# INFO:root:downloaded cat[186]
# INFO:root:downloaded cat[183]
# INFO:root:downloaded cat[184]
# INFO:root:downloaded cat[187]
# INFO:root:downloaded cat[188]
# INFO:root:downloaded cat[189]
# INFO:root:downloaded cat[190]
# INFO:root:downloaded cat[191]
# INFO:root:downloaded cat[196]
# INFO:root:downloaded cat[194]
# INFO:root:downloaded cat[195]
# INFO:root:downloaded cat[192]
# INFO:root:downloaded cat[193]
# INFO:root:downloaded cat[198]
# INFO:root:downloaded cat[197]
# INFO:root:downloaded cat[199]
# INFO:root:downloaded cat[200]
# INFO:root:downloaded cat[201]
# INFO:root:downloaded cat[203]
# INFO:root:downloaded cat[202]
# INFO:root:downloaded cat[204]
# INFO:root:downloaded cat[205]
# INFO:root:downloaded cat[206]
# INFO:root:downloaded cat[207]
# INFO:root:downloaded cat[208]
# INFO:root:downloaded cat[211]
# INFO:root:downloaded cat[209]
# INFO:root:downloaded cat[210]
# INFO:root:downloaded cat[212]
# INFO:root:downloaded cat[213]
# INFO:root:downloaded cat[215]
# INFO:root:downloaded cat[214]
# INFO:root:downloaded cat[216]
# INFO:root:downloaded cat[217]
# INFO:root:downloaded cat[218]
# INFO:root:downloaded cat[219]
# INFO:root:downloaded cat[223]
# INFO:root:downloaded cat[220]
# INFO:root:downloaded cat[222]
# INFO:root:downloaded cat[221]
# INFO:root:downloaded cat[225]
# INFO:root:downloaded cat[224]
# INFO:root:downloaded cat[226]
# INFO:root:downloaded cat[229]
# INFO:root:downloaded cat[227]
# INFO:root:downloaded cat[228]
# INFO:root:downloaded cat[230]
# INFO:root:downloaded cat[236]
# INFO:root:downloaded cat[231]
# INFO:root:downloaded cat[232]
# INFO:root:downloaded cat[233]
# INFO:root:downloaded cat[234]
# INFO:root:downloaded cat[235]
# INFO:root:downloaded cat[240]
# INFO:root:downloaded cat[237]
# INFO:root:downloaded cat[238]
# INFO:root:downloaded cat[239]
# INFO:root:downloaded cat[241]
# INFO:root:downloaded cat[243]
# INFO:root:downloaded cat[242]
# INFO:root:downloaded cat[245]
# INFO:root:downloaded cat[244]
# INFO:root:downloaded cat[246]
# INFO:root:downloaded cat[247]
# INFO:root:downloaded cat[250]
# INFO:root:downloaded cat[249]
# INFO:root:downloaded cat[248]
# INFO:root:downloaded cat[251]
# INFO:root:downloaded cat[252]
# INFO:root:downloaded cat[253]
# INFO:root:downloaded cat[254]
# INFO:root:downloaded cat[256]
# INFO:root:downloaded cat[257]
# INFO:root:downloaded cat[255]
# INFO:root:downloaded cat[258]
# INFO:root:downloaded cat[259]
# INFO:root:downloaded cat[261]
# INFO:root:downloaded cat[260]
# INFO:root:downloaded cat[262]
# INFO:root:downloaded cat[263]
# INFO:root:downloaded cat[267]
# INFO:root:downloaded cat[264]
# INFO:root:downloaded cat[266]
# INFO:root:downloaded cat[265]
# INFO:root:downloaded cat[269]
# INFO:root:downloaded cat[268]
# INFO:root:downloaded cat[270]
# INFO:root:downloaded cat[271]
# INFO:root:downloaded cat[273]
# INFO:root:downloaded cat[272]
# INFO:root:downloaded cat[274]
# INFO:root:downloaded cat[275]
# INFO:root:downloaded cat[277]
# INFO:root:downloaded cat[279]
# INFO:root:downloaded cat[278]
# INFO:root:downloaded cat[276]
# INFO:root:downloaded cat[280]
# INFO:root:downloaded cat[281]
# INFO:root:downloaded cat[282]
# INFO:root:downloaded cat[284]
# INFO:root:downloaded cat[283]
# INFO:root:downloaded cat[285]
# INFO:root:downloaded cat[288]
# INFO:root:downloaded cat[287]
# INFO:root:downloaded cat[286]
# INFO:root:downloaded cat[290]
# INFO:root:downloaded cat[291]
# INFO:root:downloaded cat[289]
# INFO:root:downloaded cat[292]
# INFO:root:downloaded cat[294]
# INFO:root:downloaded cat[293]
# INFO:root:downloaded cat[296]
# INFO:root:downloaded cat[295]
# INFO:root:downloaded cat[300]
# INFO:root:downloaded cat[298]
# INFO:root:downloaded cat[301]
# INFO:root:downloaded cat[297]
# INFO:root:downloaded cat[299]
# INFO:root:downloaded cat[302]
# INFO:root:downloaded cat[303]
# INFO:root:downloaded cat[305]
# INFO:root:downloaded cat[304]
# INFO:root:downloaded cat[306]
# INFO:root:downloaded cat[310]
# INFO:root:downloaded cat[307]
# INFO:root:downloaded cat[309]
# INFO:root:downloaded cat[308]
# INFO:root:downloaded cat[312]
# INFO:root:downloaded cat[311]
# INFO:root:downloaded cat[313]
# INFO:root:downloaded cat[314]
# INFO:root:downloaded cat[315]
# INFO:root:downloaded cat[316]
# INFO:root:downloaded cat[317]
# INFO:root:downloaded cat[318]
# INFO:root:downloaded cat[322]
# INFO:root:downloaded cat[320]
# INFO:root:downloaded cat[319]
# INFO:root:downloaded cat[321]
# INFO:root:downloaded cat[323]
# INFO:root:downloaded cat[325]
# INFO:root:downloaded cat[326]
# INFO:root:downloaded cat[324]
# INFO:root:downloaded cat[327]
# INFO:root:downloaded cat[329]
# INFO:root:downloaded cat[328]
# INFO:root:downloaded cat[330]
# INFO:root:downloaded cat[331]
# INFO:root:downloaded cat[332]
# INFO:root:downloaded cat[333]
# INFO:root:downloaded cat[335]
# INFO:root:downloaded cat[334]
# INFO:root:downloaded cat[336]
# INFO:root:downloaded cat[337]
# INFO:root:downloaded cat[341]
# INFO:root:downloaded cat[340]
# INFO:root:downloaded cat[338]
# INFO:root:downloaded cat[339]
# INFO:root:downloaded cat[342]
# INFO:root:downloaded cat[343]
# INFO:root:downloaded cat[346]
# INFO:root:downloaded cat[344]
# INFO:root:downloaded cat[345]
# INFO:root:downloaded cat[352]
# INFO:root:downloaded cat[351]
# INFO:root:downloaded cat[350]
# INFO:root:downloaded cat[348]
# INFO:root:downloaded cat[347]
# INFO:root:downloaded cat[349]
# INFO:root:downloaded cat[355]
# INFO:root:downloaded cat[354]
# INFO:root:downloaded cat[356]
# INFO:root:downloaded cat[357]
# INFO:root:downloaded cat[353]
# INFO:root:downloaded cat[359]
# INFO:root:downloaded cat[358]
# INFO:root:downloaded cat[360]
# INFO:root:downloaded cat[361]
# INFO:root:downloaded cat[363]
# INFO:root:downloaded cat[362]
# INFO:root:downloaded cat[364]
# INFO:root:downloaded cat[365]
# INFO:root:downloaded cat[366]
# INFO:root:downloaded cat[367]
# INFO:root:downloaded cat[368]
# INFO:root:downloaded cat[369]
# INFO:root:downloaded cat[370]
# INFO:root:downloaded cat[372]
# INFO:root:downloaded cat[371]
# INFO:root:downloaded cat[373]
# INFO:root:downloaded cat[374]
# INFO:root:downloaded cat[375]
# INFO:root:downloaded cat[376]
# INFO:root:downloaded cat[378]
# INFO:root:downloaded cat[377]
# INFO:root:downloaded cat[380]
# INFO:root:downloaded cat[379]
# INFO:root:downloaded cat[382]
# INFO:root:downloaded cat[383]
# INFO:root:downloaded cat[381]
# INFO:root:downloaded cat[384]
# INFO:root:downloaded cat[385]
# INFO:root:downloaded cat[386]
# INFO:root:downloaded cat[388]
# INFO:root:downloaded cat[387]
# INFO:root:downloaded cat[390]
# INFO:root:downloaded cat[389]
# INFO:root:downloaded cat[391]
# INFO:root:downloaded cat[393]
# INFO:root:downloaded cat[395]
# INFO:root:downloaded cat[392]
# INFO:root:downloaded cat[394]
# INFO:root:downloaded cat[397]
# INFO:root:downloaded cat[396]
# INFO:root:downloaded cat[398]
# INFO:root:downloaded cat[400]
# INFO:root:downloaded cat[399]
# INFO:root:downloaded cat[401]
# INFO:root:downloaded cat[402]
# INFO:root:downloaded cat[404]
# INFO:root:downloaded cat[403]
# INFO:root:downloaded cat[406]
# INFO:root:downloaded cat[405]
# INFO:root:downloaded cat[407]
# INFO:root:downloaded cat[408]
# INFO:root:downloaded cat[412]
# INFO:root:downloaded cat[410]
# INFO:root:downloaded cat[409]
# INFO:root:downloaded cat[411]
# INFO:root:downloaded cat[414]
# INFO:root:downloaded cat[413]
# INFO:root:downloaded cat[416]
# INFO:root:downloaded cat[415]
# INFO:root:downloaded cat[417]
# INFO:root:downloaded cat[418]
# INFO:root:downloaded cat[419]
# INFO:root:downloaded cat[421]
# INFO:root:downloaded cat[420]
# INFO:root:downloaded cat[422]
# INFO:root:downloaded cat[423]
# INFO:root:downloaded cat[427]
# INFO:root:downloaded cat[426]
# INFO:root:downloaded cat[424]
# INFO:root:downloaded cat[425]
# INFO:root:downloaded cat[431]
# INFO:root:downloaded cat[428]
# INFO:root:downloaded cat[429]
# INFO:root:downloaded cat[430]
# INFO:root:downloaded cat[432]
# INFO:root:downloaded cat[435]
# INFO:root:downloaded cat[436]
# INFO:root:downloaded cat[433]
# INFO:root:downloaded cat[434]
# INFO:root:downloaded cat[437]
# INFO:root:downloaded cat[438]
# INFO:root:downloaded cat[439]
# INFO:root:downloaded cat[440]
# INFO:root:downloaded cat[441]
# INFO:root:downloaded cat[442]
# INFO:root:downloaded cat[443]
# INFO:root:downloaded cat[448]
# INFO:root:downloaded cat[444]
# INFO:root:downloaded cat[445]
# INFO:root:downloaded cat[446]
# INFO:root:downloaded cat[447]
# INFO:root:downloaded cat[449]
# INFO:root:downloaded cat[450]
# INFO:root:downloaded cat[451]
# INFO:root:downloaded cat[452]
# INFO:root:downloaded cat[456]
# INFO:root:downloaded cat[453]
# INFO:root:downloaded cat[454]
# INFO:root:downloaded cat[455]
# INFO:root:downloaded cat[457]
# INFO:root:downloaded cat[458]
# INFO:root:downloaded cat[459]
# INFO:root:downloaded cat[460]
# INFO:root:downloaded cat[464]
# INFO:root:downloaded cat[461]
# INFO:root:downloaded cat[463]
# INFO:root:downloaded cat[466]
# INFO:root:downloaded cat[462]
# INFO:root:downloaded cat[465]
# INFO:root:downloaded cat[467]
# INFO:root:downloaded cat[468]
# INFO:root:downloaded cat[469]
# INFO:root:downloaded cat[470]
# INFO:root:downloaded cat[471]
# INFO:root:downloaded cat[472]
# INFO:root:downloaded cat[473]
# INFO:root:downloaded cat[474]
# INFO:root:downloaded cat[478]
# INFO:root:downloaded cat[475]
# INFO:root:downloaded cat[476]
# INFO:root:downloaded cat[477]
# INFO:root:downloaded cat[479]
# INFO:root:downloaded cat[480]
# INFO:root:downloaded cat[481]
# INFO:root:downloaded cat[482]
# INFO:root:downloaded cat[484]
# INFO:root:downloaded cat[483]
# INFO:root:downloaded cat[485]
# INFO:root:downloaded cat[488]
# INFO:root:downloaded cat[486]
# INFO:root:downloaded cat[487]
# INFO:root:downloaded cat[489]
# INFO:root:downloaded cat[491]
# INFO:root:downloaded cat[490]
# INFO:root:downloaded cat[492]
# INFO:root:downloaded cat[493]
# INFO:root:downloaded cat[496]
# INFO:root:downloaded cat[494]
# INFO:root:downloaded cat[495]
# INFO:root:downloaded cat[497]
# INFO:root:downloaded cat[498]
# INFO:root:downloaded cat[499]
# INFO:root:downloaded cat[501]
# INFO:root:downloaded cat[500]
# INFO:root:downloaded cat[502]
# INFO:root:downloaded cat[503]
# INFO:root:downloaded cat[505]
# INFO:root:downloaded cat[504]
# INFO:root:downloaded cat[506]
# INFO:root:downloaded cat[507]
# INFO:root:downloaded cat[510]
# INFO:root:downloaded cat[512]
# INFO:root:downloaded cat[509]
# INFO:root:downloaded cat[508]
# INFO:root:downloaded cat[511]
# INFO:root:downloaded cat[514]
# INFO:root:downloaded cat[513]
# INFO:root:downloaded cat[515]
# INFO:root:downloaded cat[516]
# INFO:root:downloaded cat[517]
# INFO:root:downloaded cat[519]
# INFO:root:downloaded cat[518]
# INFO:root:downloaded cat[521]
# INFO:root:downloaded cat[522]
# INFO:root:downloaded cat[520]
# INFO:root:downloaded cat[525]
# INFO:root:downloaded cat[523]
# INFO:root:downloaded cat[524]
# INFO:root:downloaded cat[528]
# INFO:root:downloaded cat[526]
# INFO:root:downloaded cat[527]
# INFO:root:downloaded cat[529]
# INFO:root:downloaded cat[532]
# INFO:root:downloaded cat[533]
# INFO:root:downloaded cat[530]
# INFO:root:downloaded cat[531]
# INFO:root:downloaded cat[534]
# INFO:root:downloaded cat[535]
# INFO:root:downloaded cat[537]
# INFO:root:downloaded cat[536]
# INFO:root:downloaded cat[539]
# INFO:root:downloaded cat[538]
# INFO:root:downloaded cat[543]
# INFO:root:downloaded cat[540]
# INFO:root:downloaded cat[541]
# INFO:root:downloaded cat[544]
# INFO:root:downloaded cat[542]
# INFO:root:downloaded cat[545]
# INFO:root:downloaded cat[546]
# INFO:root:downloaded cat[547]
# INFO:root:downloaded cat[549]
# INFO:root:downloaded cat[550]
# INFO:root:downloaded cat[548]
# INFO:root:downloaded cat[551]
# INFO:root:downloaded cat[552]
# INFO:root:downloaded cat[554]
# INFO:root:downloaded cat[553]
# INFO:root:downloaded cat[555]
# INFO:root:downloaded cat[556]
# INFO:root:downloaded cat[557]
# INFO:root:downloaded cat[560]
# INFO:root:downloaded cat[559]
# INFO:root:downloaded cat[558]
# INFO:root:downloaded cat[561]
# INFO:root:downloaded cat[563]
# INFO:root:downloaded cat[564]
# INFO:root:downloaded cat[562]
# INFO:root:downloaded cat[565]
# INFO:root:downloaded cat[566]
# INFO:root:downloaded cat[569]
# INFO:root:downloaded cat[568]
# INFO:root:downloaded cat[571]
# INFO:root:downloaded cat[570]
# INFO:root:downloaded cat[567]
# INFO:root:downloaded cat[573]
# INFO:root:downloaded cat[572]
# INFO:root:downloaded cat[574]
# INFO:root:downloaded cat[575]
# INFO:root:downloaded cat[576]
# INFO:root:downloaded cat[577]
# INFO:root:downloaded cat[578]
# INFO:root:downloaded cat[579]
# INFO:root:downloaded cat[581]
# INFO:root:downloaded cat[580]
# INFO:root:downloaded cat[582]
# INFO:root:downloaded cat[584]
# INFO:root:downloaded cat[583]
# INFO:root:downloaded cat[585]
# INFO:root:downloaded cat[586]
# INFO:root:downloaded cat[587]
# INFO:root:downloaded cat[590]
# INFO:root:downloaded cat[588]
# INFO:root:downloaded cat[591]
# INFO:root:downloaded cat[589]
# INFO:root:downloaded cat[592]
# INFO:root:downloaded cat[593]
# INFO:root:downloaded cat[594]
# INFO:root:downloaded cat[595]
# INFO:root:downloaded cat[596]
# INFO:root:downloaded cat[598]
# INFO:root:downloaded cat[597]
# INFO:root:downloaded cat[599]
# INFO:root:downloaded cat[600]
# INFO:root:downloaded cat[601]
# INFO:root:downloaded cat[602]
# INFO:root:downloaded cat[603]
# INFO:root:downloaded cat[604]
# INFO:root:downloaded cat[605]
# INFO:root:downloaded cat[607]
# INFO:root:downloaded cat[606]
# INFO:root:downloaded cat[608]
# INFO:root:downloaded cat[609]
# INFO:root:downloaded cat[612]
# INFO:root:downloaded cat[610]
# INFO:root:downloaded cat[614]
# INFO:root:downloaded cat[613]
# INFO:root:downloaded cat[611]
# INFO:root:downloaded cat[618]
# INFO:root:downloaded cat[617]
# INFO:root:downloaded cat[616]
# INFO:root:downloaded cat[615]
# INFO:root:downloaded cat[619]
# INFO:root:downloaded cat[620]
# INFO:root:downloaded cat[621]
# INFO:root:downloaded cat[624]
# INFO:root:downloaded cat[622]
# INFO:root:downloaded cat[623]
# INFO:root:downloaded cat[625]
# INFO:root:downloaded cat[626]
# INFO:root:downloaded cat[627]
# INFO:root:downloaded cat[628]
# INFO:root:downloaded cat[629]
# INFO:root:downloaded cat[634]
# INFO:root:downloaded cat[630]
# INFO:root:downloaded cat[632]
# INFO:root:downloaded cat[631]
# INFO:root:downloaded cat[633]
# INFO:root:downloaded cat[635]
# INFO:root:downloaded cat[636]
# INFO:root:downloaded cat[637]
# INFO:root:downloaded cat[638]
# INFO:root:downloaded cat[640]
# INFO:root:downloaded cat[639]
# INFO:root:downloaded cat[643]
# INFO:root:downloaded cat[641]
# INFO:root:downloaded cat[642]
# INFO:root:downloaded cat[644]
# INFO:root:downloaded cat[647]
# INFO:root:downloaded cat[645]
# INFO:root:downloaded cat[648]
# INFO:root:downloaded cat[653]
# INFO:root:downloaded cat[646]
# INFO:root:downloaded cat[649]
# INFO:root:downloaded cat[650]
# WARNING:root:failed to download cat[656]
# INFO:root:downloaded cat[651]
# INFO:root:downloaded cat[652]
# WARNING:root:failed to download cat[658]
# WARNING:root:failed to download cat[659]
# WARNING:root:failed to download cat[664]
# WARNING:root:failed to download cat[663]
# INFO:root:downloaded cat[654]
# WARNING:root:failed to download cat[665]
# INFO:root:downloaded cat[655]
# WARNING:root:failed to download cat[669]
# WARNING:root:failed to download cat[670]
# INFO:root:downloaded cat[657]
# INFO:root:downloaded cat[661]
# INFO:root:downloaded cat[662]
# INFO:root:downloaded cat[660]
# INFO:root:downloaded cat[666]
# WARNING:root:failed to download cat[675]
# WARNING:root:failed to download cat[676]
# INFO:root:downloaded cat[668]
# INFO:root:downloaded cat[667]
# INFO:root:downloaded cat[671]
# INFO:root:downloaded cat[673]
# INFO:root:downloaded cat[674]
# INFO:root:downloaded cat[672]
# WARNING:root:failed to download cat[685]
# INFO:root:downloaded cat[678]
# INFO:root:downloaded cat[677]
# INFO:root:downloaded cat[681]
# INFO:root:downloaded cat[680]
# INFO:root:downloaded cat[679]
# WARNING:root:failed to download cat[691]
# INFO:root:downloaded cat[682]
# INFO:root:downloaded cat[683]
# INFO:root:downloaded cat[686]
# INFO:root:downloaded cat[684]
# INFO:root:downloaded cat[687]
# INFO:root:downloaded cat[690]
# INFO:root:downloaded cat[689]
# WARNING:root:failed to download cat[697]
# INFO:root:downloaded cat[692]
# INFO:root:downloaded cat[688]
# INFO:root:downloaded cat[693]
# WARNING:root:failed to download cat[700]
# INFO:root:downloaded cat[694]
# INFO:root:downloaded cat[695]
# INFO:root:downloaded cat[696]
# WARNING:root:failed to download cat[707]
# INFO:root:downloaded cat[699]
# INFO:root:downloaded cat[698]
# WARNING:root:failed to download cat[706]
# INFO:root:downloaded cat[702]
# INFO:root:downloaded cat[701]
# INFO:root:downloaded cat[703]
# INFO:root:downloaded cat[704]
# INFO:root:downloaded cat[705]
# WARNING:root:failed to download cat[713]
# WARNING:root:failed to download cat[717]
# WARNING:root:failed to download cat[716]
# INFO:root:downloaded cat[708]
# INFO:root:downloaded cat[711]
# WARNING:root:failed to download cat[720]
# INFO:root:downloaded cat[712]
# INFO:root:downloaded cat[710]
# INFO:root:downloaded cat[709]
# INFO:root:downloaded cat[714]
# INFO:root:downloaded cat[715]
# WARNING:root:failed to download cat[724]
# INFO:root:downloaded cat[718]
# INFO:root:downloaded cat[719]
# INFO:root:downloaded cat[723]
# INFO:root:downloaded cat[721]
# INFO:root:downloaded cat[725]
# WARNING:root:failed to download cat[730]
# INFO:root:downloaded cat[722]
# INFO:root:downloaded cat[728]
# INFO:root:downloaded cat[726]
# INFO:root:downloaded cat[727]
# INFO:root:downloaded cat[729]
# INFO:root:downloaded cat[731]
# INFO:root:downloaded cat[733]
# INFO:root:downloaded cat[732]
# INFO:root:downloaded cat[736]
# INFO:root:downloaded cat[734]
# INFO:root:downloaded cat[738]
# INFO:root:downloaded cat[737]
# INFO:root:downloaded cat[735]
# INFO:root:downloaded cat[739]
# INFO:root:downloaded cat[741]
# INFO:root:downloaded cat[742]
# INFO:root:downloaded cat[740]
# INFO:root:downloaded cat[745]
# INFO:root:downloaded cat[743]
# INFO:root:downloaded cat[746]
# INFO:root:downloaded cat[744]
# INFO:root:downloaded cat[747]
# INFO:root:downloaded cat[749]
# INFO:root:downloaded cat[748]
# INFO:root:downloaded cat[752]
# WARNING:root:failed to download cat[757]
# INFO:root:downloaded cat[751]
# INFO:root:downloaded cat[750]
# INFO:root:downloaded cat[754]
# INFO:root:downloaded cat[753]
# INFO:root:downloaded cat[759]
# INFO:root:downloaded cat[755]
# INFO:root:downloaded cat[756]
# INFO:root:downloaded cat[758]
# INFO:root:downloaded cat[760]
# INFO:root:downloaded cat[761]

# %% [markdown]
# ### Download backgrounds

# %%
# download backgrounds

def download_backgrounds(start=0, force_download=False):
    if not os.path.exists(bg_path):
        os.mkdir(bg_path)
    elif not force_download and any((file.endswith('.png') for file in os.listdir(bg_path))):
        return

    bg_url = f'{base_url}/img/bg/bg{{id:03}}.png'
    max_index = find_max_index(bg_url)
    logging.info(f'maximum index is {max_index}')

    def download(bg_id: int):
        src = base_url.copy().add(path=f'img/bg/bg{bg_id:03}.png').url
        output_path = f'{bg_path}/bg{bg_id:003}.png'
        image = requests.get(src)
        if image.status_code == 200:
            with open(output_path, "wb") as f:
                f.write(image.content)
            logging.info(f'downloaded bg[{bg_id}]')
        else:
            logging.warning(f'failed to download bg[{bg_id}]')

    with ThreadPoolExecutor(max_workers=10) as executor:
        for i in range(start, max_index + 1):
            executor.submit(download, i)


download_backgrounds()

# %%
import cv2
import numpy as np

_cats_url = f'{base_url.url}/img/u/{{id:03}}/{{fcs}}/uni{{id:03}}_{{fcs}}00.png'
uurl = _cats_url.format(id=1, fcs='f')
req = urllib.request.urlopen(uurl)
arr = np.asarray(bytearray(req.content), dtype=np.uint8)
img = cv2.imdecode(arr, -1)  # 'Load it as it is'

cv2.imshow('lalala', img)
if cv2.waitKey() & 0xff == 27: quit()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 10
#       7 arr = np.asarray(bytearray(req.content), dtype=np.uint8)
#       8 img = cv2.imdecode(arr, -1) # 'Load it as it is'
# ---> 10 cv2.imshow('lalala', img)
#      11 if cv2.waitKey() & 0xff == 27: quit()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
import os
cats_path = 'data\\cat'
cats = [cat.path for cat in os.scandir(cats_path) if cat.name.endswith('.png')]

for cat in cats:
    try:
        img = cv2.imread(cat,cv2.IMREAD_UNCHANGED)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    except:
        print(f'failed to read cat[{cat}]')
        os.remove(cat)
